# %% [markdown]
# # Imports & setup

# %%
# Import Splinter, BeautifulSoup, and Selenium
from splinter import Browser
from bs4 import BeautifulSoup as soup
from selenium.webdriver.chrome.service import Service

# %%
# Import Pandas
import pandas as pd

# %%
# Import time datetime
import time
import datetime as dt

# %%
# Get user input for dates to loop through
start_date_str = input('Enter a start date: ')
end_date_str = input('Enter an end date: ')
# Out:
# Enter a start date:  December 8, 2023
# Enter an end date:  February 26, 2024

# %%
# Convert user input to datetime objects
start_date = dt.datetime.strptime(start_date_str, '%B %d, %Y').date()
end_date = dt.datetime.strptime(end_date_str, '%B %d, %Y').date()

# %%
# Initialize an empty list to hold the CDL data
cdl_data = []

# %%
# Helper function to decide winner of map
def return_result(our_score, opp_score):
    if our_score > opp_score:
        return 1
    return 0

# %%
# Set up Splinter

# PC
# my_service = Service(executable_path = 'C:\\Users\\David\\.wdm\\drivers\\chromedriver\\win64\\121.0.6167.184\\chromedriver-win32\\chromedriver.exe')

# Laptop
my_service = Service(executable_path = 'C:\\Users\\David Harler Jr\\.wdm\\drivers\\chromedriver\\win64\\121.0.6167.184\\chromedriver-win32\\chromedriver.exe')

browser = Browser('chrome', service=my_service)

# %% [markdown]
# # Loop through BP.gg webpages & matches

# %%
# Initialize iterator
cur_date = start_date

# Initialize row nums to loop through
row_nums = [1, 2, 3, 4, 6, 7, 8, 9]

# Print the beginning of the logging.
print("-----------------------------")
print("Beginning Data Retrieval     ")
print("-----------------------------")
print("")

# Use while loop to iterate through date range
while cur_date <= end_date:

    # Visit BP.gg matches webpage for the current date
    url = 'https://www.breakingpoint.gg/matches/' + cur_date.strftime('%Y-%m-%d')
    browser.visit(url)

    # Wait for webpage to load
    time.sleep(5)
    
    # Parse the HTML for the current date
    html = browser.html
    bp_soup = soup(html, 'html.parser')

    # Get the matches from the current date
    matches = bp_soup.find('div', class_ = 'mantine-1hiehc6')

    # Check to see if there were any matches on the current date by checking the number of descendants of the matches subtree
    if len(list(matches.descendants)) > 2:

        # Visit the webpage for each match that took place on the current date
        for match in matches.find_all('a'):
            url = 'https://www.breakingpoint.gg' + match['href']
            browser.visit(url)
            
            # Wait for webpage to load
            time.sleep(5)

            # Get the match ID
            match_id = match['href'].split('/')[2]
            
            # Parse the HTML for the current match
            match_html = browser.html
            match_soup = soup(match_html, 'html.parser')
            
            # Get the teams
            teams = match_soup.find('div', class_ = 'mantine-7o6j5m').contents[0].contents
            team_a = teams[0].contents[0].contents[0].string
            team_b = teams[1].contents[-1].contents[-1].contents[0].string

            # Get the series scores
            team_a_series_score = int(teams[1].contents[0].string)
            team_b_series_score = int(teams[1].contents[2].string)
            
            # Get the mapset and the total number of maps played for the current match
            mapset = match_soup.find('div', class_ = 'mantine-g92whd').find_all('div', class_ = 'mantine-155beqj')
            total_maps = len(mapset)
            
            # Get the scoreboards
            scoreboards = match_soup.find_all('div', class_ = 'mantine-Tabs-panel mantine-v1hkmm')
            
            # Test print statement
            print(f"{team_a} vs. {team_b} | Match {match_id} on {cur_date} ")
            
            # Iterate through each map for the current match
            for map_num in range(1, total_maps + 1):
            
                # Get the map name
                map_name = list(mapset[map_num - 1].contents[1].strings)[0]
                
                # Get the gamemode
                gamemode = mapset[map_num - 1].contents[0].string
            
                # Get the team scores
                scores = mapset[map_num - 1].contents[2].contents[1].contents
                team_a_map_score = int(scores[0].string)
                team_b_map_score = int(scores[2].string)
            
                # Test print statements
                print(f"Map {map_num} of {total_maps} | {map_name} {gamemode}")
                # print(f"{team_a} {team_a_map_score} - {team_b_map_score} {team_b}")
            
                # Iterate down the rows of the current scoreboard
                for row_num in row_nums:
            
                    # Get the player stats
                    player = scoreboards[map_num - 1].contents[0].contents[1].contents[row_num].contents[0].string
                    kills = int(scoreboards[map_num - 1].contents[0].contents[1].contents[row_num].contents[1].string)
                    deaths = int(scoreboards[map_num - 1].contents[0].contents[1].contents[row_num].contents[2].string)
                    kd = float(scoreboards[map_num - 1].contents[0].contents[1].contents[row_num].contents[3].string)
                    plus_minus = kills - deaths
                    dmg = int("".join(scoreboards[map_num - 1].contents[0].contents[1].contents[row_num].contents[5].string.split(',')))
            
                    if row_num < 5:
                        # Append data to our cdl_list 
                        cdl_data.append({"Match": match_id, "Date": cur_date, "Day": cur_date.strftime('%A'),
                                         "Player": player, "Team": team_a,
                                         "Map #": map_num, "Map": map_name, "Gamemode": gamemode, "Kills": kills, 
                                         "Deaths": deaths, "K/D": kd, "+/-": plus_minus, "Damage": dmg, 
                                         "Team Score": team_a_map_score, 
                                         "Map Result": return_result(team_a_map_score, team_b_map_score), 
                                         "Series Result": return_result(team_a_series_score, team_b_series_score)})
                    else:
                        # Append data to our cdl_list 
                        cdl_data.append({"Match": match_id, "Date": cur_date, "Day": cur_date.strftime('%A'),
                                         "Player": player, "Team": team_b,
                                         "Map #": map_num, "Map": map_name, "Gamemode": gamemode, "Kills": kills, 
                                         "Deaths": deaths, "K/D": kd, "+/-": plus_minus, "Damage": dmg, 
                                         "Team Score": team_b_map_score, 
                                         "Map Result": return_result(team_b_map_score, team_a_map_score), 
                                         "Series Result": return_result(team_b_series_score, team_a_series_score)})

            
            # Test print statement
            print(f"Series Final: {team_a} {team_a_series_score} - {team_b_series_score} {team_b}")
            print("")
    
    # Move to next date
    cur_date += dt.timedelta(days=1)

    # Indicate that Data Loading is complete.
print("")
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# -----------------------------
# Beginning Data Retrieval
# -----------------------------
#
# Atlanta FaZe vs. Boston Breach | Match 27193 on 2023-12-08
# Map 1 of 5 | Karachi Hardpoint
# Map 2 of 5 | Karachi Search & Destroy
# Map 3 of 5 | Invasion Control
# Map 4 of 5 | Terminal Hardpoint
# Map 5 of 5 | Invasion Search & Destroy
# Series Final: Atlanta FaZe 3 - 2 Boston Breach
#
# Los Angeles Thieves vs. Seattle Surge | Match 27194 on 2023-12-08
# Map 1 of 4 | Karachi Hardpoint
# Map 2 of 4 | Terminal Search & Destroy
# Map 3 of 4 | Invasion Control
# Map 4 of 4 | Terminal Hardpoint
# Series Final: Los Angeles Thieves 1 - 3 Seattle Surge
#
# OpTic Texas vs. New York Subliners | Match 27195 on 2023-12-08
# Map 1 of 5 | Karachi Hardpoint
# Map 2 of 5 | Highrise Search & Destroy
# Map 3 of 5 | Karachi Control
# Map 4 of 5 | Terminal Hardpoint
# Map 5 of 5 | Terminal Search & Destroy
# Series Final: OpTic Texas 2 - 3 New York Subliners
#
# Carolina Royal Ravens vs. Miami Heretics | Match 27196 on 2023-12-09
# Map 1 of 3 | Invasion Hardpoint
# Map 2 of 3 | Skidrow Search & Destroy
# Map 3 of 3 | Highrise Control
# Series Final: Carolina Royal Ravens 0 - 3 Miami Heretics
#
# Las Vegas Legion vs. Minnesota RØKKR | Match 27197 on 2023-12-09
# Map 1 of 5 | Skidrow Hardpoint
# Map 2 of 5 | Invasion Search & Destroy
# Map 3 of 5 | Karachi Control
# Map 4 of 5 | Sub Base Hardpoint
# Map 5 of 5 | Skidrow Search & Destroy
# Series Final: Las Vegas Legion 3 - 2 Minnesota RØKKR
#
# Toronto Ultra vs. Los Angeles Guerrillas | Match 27198 on 2023-12-09
# Map 1 of 4 | Sub Base Hardpoint
# Map 2 of 4 | Highrise Search & Destroy
# Map 3 of 4 | Karachi Control
# Map 4 of 4 | Invasion Hardpoint
# Series Final: Toronto Ultra 3 - 1 Los Angeles Guerrillas
#
# Seattle Surge vs. Boston Breach | Match 27199 on 2023-12-09
# Map 1 of 4 | Invasion Hardpoint
# Map 2 of 4 | Terminal Search & Destroy
# Map 3 of 4 | Invasion Control
# Map 4 of 4 | Terminal Hardpoint
# Series Final: Seattle Surge 3 - 1 Boston Breach
#
# Las Vegas Legion vs. Carolina Royal Ravens | Match 27200 on 2023-12-10
# Map 1 of 5 | Invasion Hardpoint
# Map 2 of 5 | Terminal Search & Destroy
# Map 3 of 5 | Invasion Control
# Map 4 of 5 | Karachi Hardpoint
# Map 5 of 5 | Invasion Search & Destroy
# Series Final: Las Vegas Legion 2 - 3 Carolina Royal Ravens
#
# New York Subliners vs. Los Angeles Guerrillas | Match 27201 on 2023-12-10
# Map 1 of 5 | Karachi Hardpoint
# Map 2 of 5 | Highrise Search & Destroy
# Map 3 of 5 | Highrise Control
# Map 4 of 5 | Sub Base Hardpoint
# Map 5 of 5 | Karachi Search & Destroy
# Series Final: New York Subliners 3 - 2 Los Angeles Guerrillas
#
# Los Angeles Thieves vs. Atlanta FaZe | Match 27202 on 2023-12-10
# Map 1 of 3 | Karachi Hardpoint
# Map 2 of 3 | Invasion Search & Destroy
# Map 3 of 3 | Invasion Control
# Series Final: Los Angeles Thieves 0 - 3 Atlanta FaZe
#
# Minnesota RØKKR vs. OpTic Texas | Match 27203 on 2023-12-10
# Map 1 of 4 | Invasion Hardpoint
# Map 2 of 4 | Karachi Search & Destroy
# Map 3 of 4 | Karachi Control
# Map 4 of 4 | Skidrow Hardpoint
# Series Final: Minnesota RØKKR 1 - 3 OpTic Texas
#
# Miami Heretics vs. Las Vegas Legion | Match 27204 on 2023-12-15
# Map 1 of 4 | Terminal Hardpoint
# Map 2 of 4 | Invasion Search & Destroy
# Map 3 of 4 | Invasion Control
# Map 4 of 4 | Invasion Hardpoint
# Series Final: Miami Heretics 3 - 1 Las Vegas Legion
#
# Los Angeles Thieves vs. Boston Breach | Match 27205 on 2023-12-15
# Map 1 of 3 | Invasion Hardpoint
# Map 2 of 3 | Invasion Search & Destroy
# Map 3 of 3 | Highrise Control
# Series Final: Los Angeles Thieves 3 - 0 Boston Breach
#
# OpTic Texas vs. Seattle Surge | Match 27206 on 2023-12-15
# Map 1 of 4 | Skidrow Hardpoint
# Map 2 of 4 | Karachi Search & Destroy
# Map 3 of 4 | Karachi Control
# Map 4 of 4 | Terminal Hardpoint
# Series Final: OpTic Texas 3 - 1 Seattle Surge
#
# Miami Heretics vs. Minnesota RØKKR | Match 27207 on 2023-12-16
# Map 1 of 4 | Terminal Hardpoint
# Map 2 of 4 | Terminal Search & Destroy
# Map 3 of 4 | Invasion Control
# Map 4 of 4 | Sub Base Hardpoint
# Series Final: Miami Heretics 3 - 1 Minnesota RØKKR
#
# Las Vegas Legion vs. New York Subliners | Match 27208 on 2023-12-16
# Map 1 of 3 | Skidrow Hardpoint
# Map 2 of 3 | Skidrow Search & Destroy
# Map 3 of 3 | Karachi Control
# Series Final: Las Vegas Legion 0 - 3 New York Subliners
#
# Atlanta FaZe vs. Seattle Surge | Match 27209 on 2023-12-16
# Map 1 of 4 | Karachi Hardpoint
# Map 2 of 4 | Highrise Search & Destroy
# Map 3 of 4 | Karachi Control
# Map 4 of 4 | Invasion Hardpoint
# Series Final: Atlanta FaZe 3 - 1 Seattle Surge
#
# Toronto Ultra vs. Carolina Royal Ravens | Match 27210 on 2023-12-16
# Map 1 of 3 | Sub Base Hardpoint
# Map 2 of 3 | Skidrow Search & Destroy
# Map 3 of 3 | Karachi Control
# Series Final: Toronto Ultra 3 - 0 Carolina Royal Ravens
#
# Carolina Royal Ravens vs. OpTic Texas | Match 27211 on 2023-12-17
# Map 1 of 3 | Skidrow Hardpoint
# Map 2 of 3 | Terminal Search & Destroy
# Map 3 of 3 | Karachi Control
# Series Final: Carolina Royal Ravens 0 - 3 OpTic Texas
#
# Los Angeles Guerrillas vs. Los Angeles Thieves | Match 27212 on 2023-12-17
# Map 1 of 3 | Sub Base Hardpoint
# Map 2 of 3 | Karachi Search & Destroy
# Map 3 of 3 | Highrise Control
# Series Final: Los Angeles Guerrillas 3 - 0 Los Angeles Thieves
#
# Boston Breach vs. Toronto Ultra | Match 27213 on 2023-12-17
# Map 1 of 3 | Terminal Hardpoint
# Map 2 of 3 | Karachi Search & Destroy
# Map 3 of 3 | Highrise Control
# Series Final: Boston Breach 3 - 0 Toronto Ultra
#
# Los Angeles Guerrillas vs. Atlanta FaZe | Match 27214 on 2024-01-12
# Map 1 of 3 | Sub Base Hardpoint
# Map 2 of 3 | Karachi Search & Destroy
# Map 3 of 3 | Invasion Control
# Series Final: Los Angeles Guerrillas 0 - 3 Atlanta FaZe
#
# Seattle Surge vs. Toronto Ultra | Match 27215 on 2024-01-12
# Map 1 of 3 | Invasion Hardpoint
# Map 2 of 3 | Karachi Search & Destroy
# Map 3 of 3 | Invasion Control
# Series Final: Seattle Surge 0 - 3 Toronto Ultra
#
# Minnesota RØKKR vs. New York Subliners | Match 27216 on 2024-01-12
# Map 1 of 4 | Terminal Hardpoint
# Map 2 of 4 | Karachi Search & Destroy
# Map 3 of 4 | Highrise Control
# Map 4 of 4 | Invasion Hardpoint
# Series Final: Minnesota RØKKR 1 - 3 New York Subliners
#
# Miami Heretics vs. Seattle Surge | Match 27217 on 2024-01-13
# Map 1 of 5 | Sub Base Hardpoint
# Map 2 of 5 | Invasion Search & Destroy
# Map 3 of 5 | Invasion Control
# Map 4 of 5 | Skidrow Hardpoint
# Map 5 of 5 | Skidrow Search & Destroy
# Series Final: Miami Heretics 2 - 3 Seattle Surge
#
# Boston Breach vs. Los Angeles Guerrillas | Match 27218 on 2024-01-13
# Map 1 of 4 | Invasion Hardpoint
# Map 2 of 4 | Karachi Search & Destroy
# Map 3 of 4 | Karachi Control
# Map 4 of 4 | Skidrow Hardpoint
# Series Final: Boston Breach 1 - 3 Los Angeles Guerrillas
#
# Toronto Ultra vs. Los Angeles Thieves | Match 27219 on 2024-01-13
# Map 1 of 4 | Invasion Hardpoint
# Map 2 of 4 | Invasion Search & Destroy
# Map 3 of 4 | Invasion Control
# Map 4 of 4 | Karachi Hardpoint
# Series Final: Toronto Ultra 3 - 1 Los Angeles Thieves
#
# OpTic Texas vs. Las Vegas Legion | Match 27220 on 2024-01-13
# Map 1 of 5 | Skidrow Hardpoint
# Map 2 of 5 | Terminal Search & Destroy
# Map 3 of 5 | Highrise Control
# Map 4 of 5 | Terminal Hardpoint
# Map 5 of 5 | Invasion Search & Destroy
# Series Final: OpTic Texas 3 - 2 Las Vegas Legion
#
# Las Vegas Legion vs. Atlanta FaZe | Match 27221 on 2024-01-14
# Map 1 of 3 | Terminal Hardpoint
# Map 2 of 3 | Skidrow Search & Destroy
# Map 3 of 3 | Highrise Control
# Series Final: Las Vegas Legion 0 - 3 Atlanta FaZe
#
# Minnesota RØKKR vs. Carolina Royal Ravens | Match 27222 on 2024-01-14
# Map 1 of 3 | Invasion Hardpoint
# Map 2 of 3 | Highrise Search & Destroy
# Map 3 of 3 | Invasion Control
# Series Final: Minnesota RØKKR 3 - 0 Carolina Royal Ravens
#
# New York Subliners vs. Los Angeles Thieves | Match 27223 on 2024-01-14
# Map 1 of 4 | Skidrow Hardpoint
# Map 2 of 4 | Skidrow Search & Destroy
# Map 3 of 4 | Invasion Control
# Map 4 of 4 | Karachi Hardpoint
# Series Final: New York Subliners 3 - 1 Los Angeles Thieves
#
# Boston Breach vs. Miami Heretics | Match 27224 on 2024-01-14
# Map 1 of 4 | Karachi Hardpoint
# Map 2 of 4 | Terminal Search & Destroy
# Map 3 of 4 | Highrise Control
# Map 4 of 4 | Invasion Hardpoint
# Series Final: Boston Breach 3 - 1 Miami Heretics
#
# Minnesota RØKKR vs. Los Angeles Guerrillas | Match 27225 on 2024-01-19
# Map 1 of 3 | Invasion Hardpoint
# Map 2 of 3 | Highrise Search & Destroy
# Map 3 of 3 | Karachi Control
# Series Final: Minnesota RØKKR 3 - 0 Los Angeles Guerrillas
#
# OpTic Texas vs. Miami Heretics | Match 27226 on 2024-01-19
# Map 1 of 3 | Invasion Hardpoint
# Map 2 of 3 | Invasion Search & Destroy
# Map 3 of 3 | Karachi Control
# Series Final: OpTic Texas 0 - 3 Miami Heretics
#
# New York Subliners vs. Toronto Ultra | Match 27227 on 2024-01-19
# Map 1 of 3 | Karachi Hardpoint
# Map 2 of 3 | Karachi Search & Destroy
# Map 3 of 3 | Karachi Control
# Series Final: New York Subliners 0 - 3 Toronto Ultra
#
# Toronto Ultra vs. Las Vegas Legion | Match 27228 on 2024-01-20
# Map 1 of 4 | Sub Base Hardpoint
# Map 2 of 4 | Skidrow Search & Destroy
# Map 3 of 4 | Highrise Control
# Map 4 of 4 | Invasion Hardpoint
# Series Final: Toronto Ultra 3 - 1 Las Vegas Legion
#
# Miami Heretics vs. Los Angeles Guerrillas | Match 27229 on 2024-01-20
# Map 1 of 3 | Terminal Hardpoint
# Map 2 of 3 | Invasion Search & Destroy
# Map 3 of 3 | Karachi Control
# Series Final: Miami Heretics 3 - 0 Los Angeles Guerrillas
#
# Seattle Surge vs. Minnesota RØKKR | Match 27230 on 2024-01-20
# Map 1 of 5 | Skidrow Hardpoint
# Map 2 of 5 | Invasion Search & Destroy
# Map 3 of 5 | Karachi Control
# Map 4 of 5 | Terminal Hardpoint
# Map 5 of 5 | Karachi Search & Destroy
# Series Final: Seattle Surge 2 - 3 Minnesota RØKKR
#
# Atlanta FaZe vs. Carolina Royal Ravens | Match 27231 on 2024-01-20
# Map 1 of 5 | Skidrow Hardpoint
# Map 2 of 5 | Highrise Search & Destroy
# Map 3 of 5 | Karachi Control
# Map 4 of 5 | Sub Base Hardpoint
# Map 5 of 5 | Skidrow Search & Destroy
# Series Final: Atlanta FaZe 3 - 2 Carolina Royal Ravens
#
# Carolina Royal Ravens vs. Los Angeles Thieves | Match 27232 on 2024-01-21
# Map 1 of 5 | Sub Base Hardpoint
# Map 2 of 5 | Terminal Search & Destroy
# Map 3 of 5 | Invasion Control
# Map 4 of 5 | Karachi Hardpoint
# Map 5 of 5 | Karachi Search & Destroy
# Series Final: Carolina Royal Ravens 2 - 3 Los Angeles Thieves
#
# New York Subliners vs. Boston Breach | Match 27233 on 2024-01-21
# Map 1 of 5 | Skidrow Hardpoint
# Map 2 of 5 | Karachi Search & Destroy
# Map 3 of 5 | Highrise Control
# Map 4 of 5 | Invasion Hardpoint
# Map 5 of 5 | Highrise Search & Destroy
# Series Final: New York Subliners 3 - 2 Boston Breach
#
# Atlanta FaZe vs. OpTic Texas | Match 27234 on 2024-01-21
# Map 1 of 3 | Invasion Hardpoint
# Map 2 of 3 | Invasion Search & Destroy
# Map 3 of 3 | Highrise Control
# Series Final: Atlanta FaZe 3 - 0 OpTic Texas
#
# Atlanta FaZe vs. Los Angeles Guerrillas | Match 35633 on 2024-01-25
# Map 1 of 3 | Skidrow Hardpoint
# Map 2 of 3 | Invasion Search & Destroy
# Map 3 of 3 | Invasion Control
# Series Final: Atlanta FaZe 3 - 0 Los Angeles Guerrillas
#
# New York Subliners vs. Minnesota RØKKR | Match 35636 on 2024-01-25
# Map 1 of 3 | Invasion Hardpoint
# Map 2 of 3 | Karachi Search & Destroy
# Map 3 of 3 | Karachi Control
# Series Final: New York Subliners 0 - 3 Minnesota RØKKR
#
# Toronto Ultra vs. Seattle Surge | Match 35635 on 2024-01-25
# Map 1 of 3 | Skidrow Hardpoint
# Map 2 of 3 | Skidrow Search & Destroy
# Map 3 of 3 | Karachi Control
# Series Final: Toronto Ultra 3 - 0 Seattle Surge
#
# Miami Heretics vs. OpTic Texas | Match 35634 on 2024-01-25
# Map 1 of 3 | Skidrow Hardpoint
# Map 2 of 3 | Invasion Search & Destroy
# Map 3 of 3 | Karachi Control
# Series Final: Miami Heretics 0 - 3 OpTic Texas
#
# New York Subliners vs. Carolina Royal Ravens | Match 35641 on 2024-01-26
# Map 1 of 4 | Karachi Hardpoint
# Map 2 of 4 | Invasion Search & Destroy
# Map 3 of 4 | Karachi Control
# Map 4 of 4 | Terminal Hardpoint
# Series Final: New York Subliners 1 - 3 Carolina Royal Ravens
#
# Los Angeles Guerrillas vs. Los Angeles Thieves | Match 35642 on 2024-01-26
# Map 1 of 4 | Karachi Hardpoint
# Map 2 of 4 | Invasion Search & Destroy
# Map 3 of 4 | Karachi Control
# Map 4 of 4 | Skidrow Hardpoint
# Series Final: Los Angeles Guerrillas 3 - 1 Los Angeles Thieves
#
# Miami Heretics vs. Las Vegas Legion | Match 35643 on 2024-01-26
# Map 1 of 3 | Invasion Hardpoint
# Map 2 of 3 | Karachi Search & Destroy
# Map 3 of 3 | Invasion Control
# Series Final: Miami Heretics 0 - 3 Las Vegas Legion
#
# Seattle Surge vs. Boston Breach | Match 35644 on 2024-01-26
# Map 1 of 5 | Sub Base Hardpoint
# Map 2 of 5 | Invasion Search & Destroy
# Map 3 of 5 | Karachi Control
# Map 4 of 5 | Karachi Hardpoint
# Map 5 of 5 | Highrise Search & Destroy
# Series Final: Seattle Surge 3 - 2 Boston Breach
#
# Los Angeles Guerrillas vs. Las Vegas Legion | Match 35645 on 2024-01-26
# Map 1 of 5 | Skidrow Hardpoint
# Map 2 of 5 | Invasion Search & Destroy
# Map 3 of 5 | Highrise Control
# Map 4 of 5 | Karachi Hardpoint
# Map 5 of 5 | Terminal Search & Destroy
# Series Final: Los Angeles Guerrillas 3 - 2 Las Vegas Legion
#
# Seattle Surge vs. Carolina Royal Ravens | Match 35646 on 2024-01-27
# Map 1 of 5 | Karachi Hardpoint
# Map 2 of 5 | Karachi Search & Destroy
# Map 3 of 5 | Invasion Control
# Map 4 of 5 | Invasion Hardpoint
# Map 5 of 5 | Terminal Search & Destroy
# Series Final: Seattle Surge 3 - 2 Carolina Royal Ravens
#
# Atlanta FaZe vs. OpTic Texas | Match 35647 on 2024-01-27
# Map 1 of 5 | Sub Base Hardpoint
# Map 2 of 5 | Invasion Search & Destroy
# Map 3 of 5 | Highrise Control
# Map 4 of 5 | Invasion Hardpoint
# Map 5 of 5 | Highrise Search & Destroy
# Series Final: Atlanta FaZe 3 - 2 OpTic Texas
#
# Toronto Ultra vs. Minnesota RØKKR | Match 35648 on 2024-01-27
# Map 1 of 3 | Skidrow Hardpoint
# Map 2 of 3 | Karachi Search & Destroy
# Map 3 of 3 | Invasion Control
# Series Final: Toronto Ultra 3 - 0 Minnesota RØKKR
#
# OpTic Texas vs. Seattle Surge | Match 35649 on 2024-01-27
# Map 1 of 4 | Sub Base Hardpoint
# Map 2 of 4 | Terminal Search & Destroy
# Map 3 of 4 | Invasion Control
# Map 4 of 4 | Terminal Hardpoint
# Series Final: OpTic Texas 3 - 1 Seattle Surge
#
# Minnesota RØKKR vs. Los Angeles Guerrillas | Match 35650 on 2024-01-27
# Map 1 of 5 | Karachi Hardpoint
# Map 2 of 5 | Invasion Search & Destroy
# Map 3 of 5 | Invasion Control
# Map 4 of 5 | Skidrow Hardpoint
# Map 5 of 5 | Terminal Search & Destroy
# Series Final: Minnesota RØKKR 3 - 2 Los Angeles Guerrillas
#
# Minnesota RØKKR vs. OpTic Texas | Match 35651 on 2024-01-28
# Map 1 of 4 | Invasion Hardpoint
# Map 2 of 4 | Karachi Search & Destroy
# Map 3 of 4 | Invasion Control
# Map 4 of 4 | Skidrow Hardpoint
# Series Final: Minnesota RØKKR 1 - 3 OpTic Texas
#
# Atlanta FaZe vs. Toronto Ultra | Match 35652 on 2024-01-28
# Map 1 of 4 | Karachi Hardpoint
# Map 2 of 4 | Invasion Search & Destroy
# Map 3 of 4 | Invasion Control
# Map 4 of 4 | Sub Base Hardpoint
# Series Final: Atlanta FaZe 1 - 3 Toronto Ultra
#
# Atlanta FaZe vs. OpTic Texas | Match 35653 on 2024-01-28
# Map 1 of 4 | Terminal Hardpoint
# Map 2 of 4 | Invasion Search & Destroy
# Map 3 of 4 | Invasion Control
# Map 4 of 4 | Invasion Hardpoint
# Series Final: Atlanta FaZe 3 - 1 OpTic Texas
#
# Toronto Ultra vs. Atlanta FaZe | Match 35654 on 2024-01-28
# Map 1 of 5 | Karachi Hardpoint
# Map 2 of 5 | Skidrow Search & Destroy
# Map 3 of 5 | Invasion Control
# Map 4 of 5 | Skidrow Hardpoint
# Map 5 of 5 | Karachi Search & Destroy
# Series Final: Toronto Ultra 4 - 1 Atlanta FaZe
#
# Miami Heretics vs. Toronto Ultra | Match 27235 on 2024-02-16
# Map 1 of 3 | Rio Hardpoint
# Map 2 of 3 | Rio Search & Destroy
# Map 3 of 3 | Karachi Control
# Series Final: Miami Heretics 0 - 3 Toronto Ultra
#
# Carolina Royal Ravens vs. New York Subliners | Match 27236 on 2024-02-16
# Map 1 of 5 | Sub Base Hardpoint
# Map 2 of 5 | Invasion Search & Destroy
# Map 3 of 5 | Highrise Control
# Map 4 of 5 | Invasion Hardpoint
# Map 5 of 5 | Karachi Search & Destroy
# Series Final: Carolina Royal Ravens 2 - 3 New York Subliners
#
# Boston Breach vs. Carolina Royal Ravens | Match 27237 on 2024-02-17
# Map 1 of 4 | Invasion Hardpoint
# Map 2 of 4 | Terminal Search & Destroy
# Map 3 of 4 | Highrise Control
# Map 4 of 4 | Karachi Hardpoint
# Series Final: Boston Breach 3 - 1 Carolina Royal Ravens
#
# Atlanta FaZe vs. Miami Heretics | Match 27238 on 2024-02-17
# Map 1 of 4 | Sub Base Hardpoint
# Map 2 of 4 | Highrise Search & Destroy
# Map 3 of 4 | Karachi Control
# Map 4 of 4 | Rio Hardpoint
# Series Final: Atlanta FaZe 3 - 1 Miami Heretics
#
# New York Subliners vs. Seattle Surge | Match 27239 on 2024-02-17
# Map 1 of 3 | Sub Base Hardpoint
# Map 2 of 3 | Terminal Search & Destroy
# Map 3 of 3 | Highrise Control
# Series Final: New York Subliners 3 - 0 Seattle Surge
#
# Los Angeles Guerrillas vs. Las Vegas Legion | Match 27240 on 2024-02-18
# Map 1 of 4 | Karachi Hardpoint
# Map 2 of 4 | Invasion Search & Destroy
# Map 3 of 4 | Highrise Control
# Map 4 of 4 | Rio Hardpoint
# Series Final: Los Angeles Guerrillas 1 - 3 Las Vegas Legion
#
# Toronto Ultra vs. Minnesota RØKKR | Match 27241 on 2024-02-18
# Map 1 of 5 | Skidrow Hardpoint
# Map 2 of 5 | Karachi Search & Destroy
# Map 3 of 5 | Karachi Control
# Map 4 of 5 | Rio Hardpoint
# Map 5 of 5 | Invasion Search & Destroy
# Series Final: Toronto Ultra 3 - 2 Minnesota RØKKR
#
# Los Angeles Thieves vs. OpTic Texas | Match 27242 on 2024-02-18
# Map 1 of 3 | Rio Hardpoint
# Map 2 of 3 | Karachi Search & Destroy
# Map 3 of 3 | Invasion Control
# Series Final: Los Angeles Thieves 0 - 3 OpTic Texas
#
# New York Subliners vs. Boston Breach | Match 27243 on 2024-02-23
# Map 1 of 3 | Skidrow Hardpoint
# Map 2 of 3 | Invasion Search & Destroy
# Map 3 of 3 | Highrise Control
# Series Final: New York Subliners 3 - 0 Boston Breach
#
# Minnesota RØKKR vs. OpTic Texas | Match 27244 on 2024-02-23
# Map 1 of 5 | Rio Hardpoint
# Map 2 of 5 | Terminal Search & Destroy
# Map 3 of 5 | Karachi Control
# Map 4 of 5 | Sub Base Hardpoint
# Map 5 of 5 | Karachi Search & Destroy
# Series Final: Minnesota RØKKR 2 - 3 OpTic Texas
#
# Miami Heretics vs. Las Vegas Legion | Match 27245 on 2024-02-23
# Map 1 of 5 | Invasion Hardpoint
# Map 2 of 5 | Karachi Search & Destroy
# Map 3 of 5 | Invasion Control
# Map 4 of 5 | Rio Hardpoint
# Map 5 of 5 | Invasion Search & Destroy
# Series Final: Miami Heretics 2 - 3 Las Vegas Legion
#
# Las Vegas Legion vs. Toronto Ultra | Match 27246 on 2024-02-24
# Map 1 of 4 | Rio Hardpoint
# Map 2 of 4 | Rio Search & Destroy
# Map 3 of 4 | Highrise Control
# Map 4 of 4 | Karachi Hardpoint
# Series Final: Las Vegas Legion 1 - 3 Toronto Ultra
#
# Los Angeles Guerrillas vs. OpTic Texas | Match 27247 on 2024-02-24
# Map 1 of 4 | Karachi Hardpoint
# Map 2 of 4 | Rio Search & Destroy
# Map 3 of 4 | Karachi Control
# Map 4 of 4 | Skidrow Hardpoint
# Series Final: Los Angeles Guerrillas 1 - 3 OpTic Texas
#
# Miami Heretics vs. Los Angeles Thieves | Match 27248 on 2024-02-24
# Map 1 of 5 | Karachi Hardpoint
# Map 2 of 5 | Karachi Search & Destroy
# Map 3 of 5 | Highrise Control
# Map 4 of 5 | Invasion Hardpoint
# Map 5 of 5 | Terminal Search & Destroy
# Series Final: Miami Heretics 2 - 3 Los Angeles Thieves
#
# Seattle Surge vs. Carolina Royal Ravens | Match 27249 on 2024-02-25
# Map 1 of 4 | Skidrow Hardpoint
# Map 2 of 4 | Terminal Search & Destroy
# Map 3 of 4 | Highrise Control
# Map 4 of 4 | Rio Hardpoint
# Series Final: Seattle Surge 1 - 3 Carolina Royal Ravens
#
# Minnesota RØKKR vs. Boston Breach | Match 27250 on 2024-02-25
# Map 1 of 5 | Invasion Hardpoint
# Map 2 of 5 | Invasion Search & Destroy
# Map 3 of 5 | Invasion Control
# Map 4 of 5 | Sub Base Hardpoint
# Map 5 of 5 | Karachi Search & Destroy
# Series Final: Minnesota RØKKR 2 - 3 Boston Breach
#
# Atlanta FaZe vs. New York Subliners | Match 27251 on 2024-02-25
# Map 1 of 5 | Karachi Hardpoint
# Map 2 of 5 | Highrise Search & Destroy
# Map 3 of 5 | Karachi Control
# Map 4 of 5 | Skidrow Hardpoint
# Map 5 of 5 | Invasion Search & Destroy
# Series Final: Atlanta FaZe 2 - 3 New York Subliners
#
#
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert our list of cdl dictionaries to a dataframe
cdl_df = pd.DataFrame(cdl_data)
cdl_df
# Out:
#       Match        Date     Day    Player                Team  Map #  \
# 0     27193  2023-12-08  Friday     aBeZy        Atlanta FaZe      1
# 1     27193  2023-12-08  Friday   Cellium        Atlanta FaZe      1
# 2     27193  2023-12-08  Friday    Drazah        Atlanta FaZe      1
# 3     27193  2023-12-08  Friday      Simp        Atlanta FaZe      1
# 4     27193  2023-12-08  Friday  Capsidal       Boston Breach      1
# ...     ...         ...     ...       ...                 ...    ...
# 2435  27251  2024-02-25  Sunday      Simp        Atlanta FaZe      5
# 2436  27251  2024-02-25  Sunday     HyDra  New York Subliners      5
# 2437  27251  2024-02-25  Sunday    KiSMET  New York Subliners      5
# 2438  27251  2024-02-25  Sunday       Sib  New York Subliners      5
# 2439  27251  2024-02-25  Sunday      Skyz  New York Subliners      5
#
#            Map          Gamemode  Kills  Deaths   K/D  +/-  Damage Team Score  \
# 0      Karachi         Hardpoint     24      24  1.00    0    4659        250
# 1      Karachi         Hardpoint     21      19  1.11    2    4032        250
# 2      Karachi         Hardpoint     25      22  1.14    3    4296        250
# 3      Karachi         Hardpoint     33      23  1.43   10    5188        250
# 4      Karachi         Hardpoint     24      26  0.92   -2    3731        238
# ...        ...               ...    ...     ...   ...  ...     ...        ...
# 2435  Invasion  Search & Destroy      7       9  0.78   -2    1158          4
# 2436  Invasion  Search & Destroy     11       7  1.57    4    2104          6
# 2437  Invasion  Search & Destroy     10       5  2.00    5    1560          6
# 2438  Invasion  Search & Destroy      3       8  0.38   -5    1014          6
# 2439  Invasion  Search & Destroy      8       5  1.60    3    2530          6
#
#       Map Result  Series Result
# 0              1              1
# 1              1              1
# 2              1              1
# 3              1              1
# 4              0              0
# ...          ...            ...
# 2435           0              0
# 2436           1              1
# 2437           1              1
# 2438           1              1
# 2439           1              1
#
# [2440 rows x 16 columns]

# %% [markdown]
# # Export data

# %%
from sqlalchemy import create_engine
from config import db_password

# %%
# Connect to SQL db
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/cdl_db"
engine = create_engine(db_string)
cdl_df.to_sql(name = 'CDL_Data', con = engine, if_exists = 'replace')
# Out:
# 440
